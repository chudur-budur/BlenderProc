# %% [markdown]
# # Introduction to BlenderProc

# %% [markdown]
# Note: This notebook makes use of the basic example which is available under `examples/basic`
#
# In this notebook, we will see how can we quickly set up the BlenderProc environment inside Google Colab and how can we generate photorealistic data which can later be used for many different applications.

# %% [markdown]
# We firstly clone the official BlenderProc repo (repository) from GitHub using Git

# %%
# git clone the BlenderProc repo
# !git clone https://github.com/DLR-RM/BlenderProc.git

# %% [markdown]
# We change our present working directory to the BlenderProc repo

# %%
 # change directory to BlenderProc
 # %cd "BlenderProc"

# %% [markdown]
# We view the present working directory to make sure we are inside the BlenderProc repo

# %%
# present working directory 
# !pwd

# %% [markdown]
# In order to run BlenderProc inside Google Colab, we first have to update the `LD_PRELOAD` environment variable

# %%
import os

# updating the LD_PRELOAD env variable
os.environ["LD_PRELOAD"] = "/usr/lib/x86_64-linux-gnu/libtcmalloc_minimal.so.4.3.0"

# %% [markdown]
# Then, we update the `blender_install_path` config variable in the `config.yaml` file inside the basic example. The reason for making this change is that we want to specify the custom Blender install path as an argument in the next step.

# %%
import yaml
import os

# load the basic example config file
with open("config.yaml", "r") as f:
  config = yaml.safe_load(f)

# update the "blender_install_path" variable with the correct Blender installation path 
home = os.environ['HOME']
config["setup"]["blender_install_path"] = os.path.join(home, 'opt/blender-2.91.0-linux64')

# write the basic example config file after making the change
with open("config.yaml", "w") as f:
  yaml.dump(config, f)

# %% [markdown]
# Finally, we run the BlenderProc program using the `run.py` file along with required command line arguments. The first argument specifies the location of the YAML config file. The second argument corresponds to the camera pose file. In this case, we have specified two camera poses in the `examples/basic/camera_positions` file. The third argument correponds to the output directory where our generated data will be stored. The fourth argument corresponds to the custom Blender install path which will be installed in the current directory by the `run.py` file.

# %%
# run the BlenderProc basic example
# !python run.py examples/basic/config.yaml examples/basic/camera_positions examples/basic/scene.obj examples/basic/output ./
# !python ../../run.py ~/nodlabs/BlenderProc/examples/basic/config.yaml ~/nodlabs/BlenderProc/examples/basic/camera_positions ~/nodlabs/BlenderProc/examples/basic/scene-base-station.obj ~/nodlabs/BlenderProc/examples/basic/output ./ --custom-blender-path $HOME/opt/blender-2.91.0-linux64
# Out:
# Parsing config '/home/khaled/nodlabs/BlenderProc/examples/basic/config.yaml'
# Filling placeholder <args:2> at modules/(main.Initializer)/config/global/output_dir: /home/khaled/nodlabs/BlenderProc/examples/basic/output
# Filling placeholder <args:1> at modules/(loader.ObjectLoader)/config/path: /home/khaled/nodlabs/BlenderProc/examples/basic/scene-base-station.obj
# Filling placeholder <args:0> at modules/(camera.CameraLoader)/config/path: /home/khaled/nodlabs/BlenderProc/examples/basic/camera_positions
# Successfully finished parsing
# Using blender in /home/khaled/opt/blender-2.91.0-linux64
# Using temporary directory: /dev/shm/blender_proc_da10daa34abf4235a44766d0dd627bbb
# Blender 2.91.0 (hash 0f45cab862b8 built 2020-11-25 08:51:08)
# /run/user/1000/gvfs/ non-existent directory
# found bundled python: /home/khaled/opt/blender-2.91.0-linux64/2.91/python
# Looking in links: /tmp/tmpn_m_1c1w
# Requirement already satisfied: setuptools in /home/khaled/opt/blender-2.91.0-linux64/2.91/python/lib/python3.7/site-packages (41.2.0)
# Requirement already satisfied: pip in /home/khaled/opt/blender-2.91.0-linux64/2.91/python/lib/python3.7/site-packages (21.1.2)
# Requirement already satisfied: pip in /home/khaled/opt/blender-2.91.0-linux64/2.91/python/lib/python3.7/site-packages (21.1.2)
# #### Start - Initializing module main.Initializer ####
# #### Finished - Initializing module main.Initializer (took 0.199 seconds) ####
# #### Start - Initializing module loader.ObjectLoader ####
# #### Finished - Initializing module loader.ObjectLoader (took 0.021 seconds) ####
# #### Start - Initializing module lighting.LightLoader ####
# #### Finished - Initializing module lighting.LightLoader (took 0.005 seconds) ####
# #### Start - Initializing module camera.CameraLoader ####
# #### Finished - Initializing module camera.CameraLoader (took 0.003 seconds) ####
# #### Start - Initializing module renderer.RgbRenderer ####
# #### Finished - Initializing module renderer.RgbRenderer (took 0.009 seconds) ####
# #### Start - Initializing module writer.Hdf5Writer ####
# #### Start - Initializing module postprocessing.TrimRedundantChannels ####
# #### Finished - Initializing module postprocessing.TrimRedundantChannels (took 0.004 seconds) ####
# #### Finished - Initializing module writer.Hdf5Writer (took 0.008 seconds) ####
# #### Start - Running blender pipeline ####
# #### Start - Running module InitializerModule ####
# #### Finished - Running module InitializerModule (took 0.003 seconds) ####
# #### Start - Running module ObjectLoaderModule ####
# (  0.0001 sec |   0.0001 sec) Importing OBJ '/home/khaled/nodlabs/BlenderProc/examples/basic/scene-base-station.obj'...
#   (  0.0002 sec |   0.0001 sec) Parsing OBJ file...
#     (  1.2162 sec |   1.2160 sec) Done, loading materials and images...
#     (  1.2192 sec |   1.2190 sec) Done, building geometries (verts:43357 faces:86820 materials: 8 smoothgroups:1) ...
#     (  2.3933 sec |   2.3932 sec) Done.
#   (  2.3934 sec |   2.3933 sec) Finished importing: '/home/khaled/nodlabs/BlenderProc/examples/basic/scene-base-station.obj'
# Progress: 100.00%
#
# #### Finished - Running module ObjectLoaderModule (took 2.436 seconds) ####
# #### Start - Running module LightLoader ####
# #### Finished - Running module LightLoader (took 0.000 seconds) ####
# #### Start - Running module CameraLoader ####
# #### Finished - Running module CameraLoader (took 0.001 seconds) ####
# #### Start - Running module RgbRenderer ####
# Resolution: 512, 512
# Fra:0 Mem:66.39M (Peak 80.46M) | Time:00:00.08 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Synchronizing object | Cube.001
# Fra:0 Mem:66.40M (Peak 80.46M) | Time:00:00.08 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Synchronizing object | Cube.002
# Fra:0 Mem:66.40M (Peak 80.46M) | Time:00:00.08 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Synchronizing object | 00_charging_station_20210524
# Fra:0 Mem:72.31M (Peak 96.72M) | Time:00:00.19 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Initializing
# Fra:0 Mem:59.67M (Peak 96.72M) | Time:00:00.19 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Waiting for render to start
# Fra:0 Mem:59.68M (Peak 96.72M) | Time:00:00.19 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Loading render kernels (may take a few minutes the first time)
# Fra:0 Mem:59.68M (Peak 96.72M) | Time:00:00.19 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Updating Scene
# Fra:0 Mem:59.68M (Peak 96.72M) | Time:00:00.19 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Updating Shaders
# Fra:0 Mem:60.19M (Peak 96.72M) | Time:00:00.33 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Updating Background
# Fra:0 Mem:60.19M (Peak 96.72M) | Time:00:00.33 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Updating Camera
# Fra:0 Mem:60.19M (Peak 96.72M) | Time:00:00.33 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Updating Meshes Flags
# Fra:0 Mem:60.19M (Peak 96.72M) | Time:00:00.33 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Updating Objects
# Fra:0 Mem:60.19M (Peak 96.72M) | Time:00:00.33 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Updating Objects | Copying Transformations to device
# Fra:0 Mem:60.19M (Peak 96.72M) | Time:00:00.33 | Mem:0.01M, Peak:0.01M | Scene, View Layer | Updating Objects | Applying Static Transformations
# Fra:0 Mem:60.19M (Peak 96.72M) | Time:00:00.33 | Mem:0.01M, Peak:0.01M | Scene, View Layer | Updating Particle Systems
# Fra:0 Mem:60.19M (Peak 96.72M) | Time:00:00.33 | Mem:0.01M, Peak:0.01M | Scene, View Layer | Updating Particle Systems | Copying Particles to device
# Fra:0 Mem:60.19M (Peak 96.72M) | Time:00:00.33 | Mem:0.01M, Peak:0.01M | Scene, View Layer | Updating Meshes
# Fra:0 Mem:61.52M (Peak 96.72M) | Time:00:00.33 | Mem:0.01M, Peak:0.01M | Scene, View Layer | Updating Mesh | Computing attributes
# Fra:0 Mem:62.47M (Peak 96.72M) | Time:00:00.33 | Mem:0.01M, Peak:0.01M | Scene, View Layer | Updating Mesh | Copying Attributes to device
# Fra:0 Mem:62.47M (Peak 96.72M) | Time:00:00.33 | Mem:0.96M, Peak:0.96M | Scene, View Layer | Updating Scene BVH | Building
# Fra:0 Mem:62.47M (Peak 96.72M) | Time:00:00.33 | Mem:0.96M, Peak:0.96M | Scene, View Layer | Updating Scene BVH | Building BVH
# Fra:0 Mem:63.79M (Peak 96.72M) | Time:00:00.37 | Mem:6.66M, Peak:6.66M | Scene, View Layer | Updating Scene BVH | Building BVH 0%
# Fra:0 Mem:68.10M (Peak 96.72M) | Time:00:00.43 | Mem:5.66M, Peak:9.66M | Scene, View Layer | Updating Scene BVH | Packing geometry
# Fra:0 Mem:67.77M (Peak 96.72M) | Time:00:00.43 | Mem:5.66M, Peak:9.66M | Scene, View Layer | Updating Scene BVH | Copying BVH to device
# Fra:0 Mem:68.10M (Peak 96.72M) | Time:00:00.43 | Mem:10.96M, Peak:10.96M | Scene, View Layer | Updating Mesh | Computing normals
# Fra:0 Mem:71.51M (Peak 96.72M) | Time:00:00.43 | Mem:10.96M, Peak:10.96M | Scene, View Layer | Updating Mesh | Copying Mesh to device
# Fra:0 Mem:71.18M (Peak 96.72M) | Time:00:00.43 | Mem:14.37M, Peak:14.37M | Scene, View Layer | Updating Objects Flags
# Fra:0 Mem:71.18M (Peak 96.72M) | Time:00:00.43 | Mem:14.37M, Peak:14.37M | Scene, View Layer | Updating Images
# Fra:0 Mem:71.18M (Peak 96.72M) | Time:00:00.43 | Mem:14.37M, Peak:14.37M | Scene, View Layer | Updating Camera Volume
# Fra:0 Mem:71.18M (Peak 96.72M) | Time:00:00.43 | Mem:14.37M, Peak:14.37M | Scene, View Layer | Updating Lookup Tables
# Fra:0 Mem:71.18M (Peak 96.72M) | Time:00:00.43 | Mem:14.62M, Peak:14.62M | Scene, View Layer | Updating Lights
# Fra:0 Mem:71.18M (Peak 96.72M) | Time:00:00.43 | Mem:14.62M, Peak:14.62M | Scene, View Layer | Updating Lights | Computing distribution
# Fra:0 Mem:71.18M (Peak 96.72M) | Time:00:00.43 | Mem:14.62M, Peak:14.62M | Scene, View Layer | Updating Integrator
# Fra:0 Mem:72.45M (Peak 96.72M) | Time:00:00.43 | Mem:15.89M, Peak:15.89M | Scene, View Layer | Updating Film
# Fra:0 Mem:72.45M (Peak 96.72M) | Time:00:00.43 | Mem:15.64M, Peak:15.89M | Scene, View Layer | Updating Lookup Tables
# Fra:0 Mem:72.45M (Peak 96.72M) | Time:00:00.43 | Mem:15.89M, Peak:15.89M | Scene, View Layer | Updating Baking
# Fra:0 Mem:72.45M (Peak 96.72M) | Time:00:00.43 | Mem:15.89M, Peak:15.89M | Scene, View Layer | Updating Device | Writing constant memory
# Fra:0 Mem:72.45M (Peak 96.72M) | Time:00:00.43 | Mem:15.89M, Peak:15.89M | Scene, View Layer | Updating Device | Writing constant memory | Compiling render kernels
# Fra:0 Mem:72.45M (Peak 96.72M) | Time:00:00.43 | Mem:15.89M, Peak:15.89M | Scene, View Layer | Updating Device | Writing constant memory
# Fra:0 Mem:72.45M (Peak 96.72M) | Time:00:00.43 | Mem:15.89M, Peak:15.89M | Scene, View Layer | Rendered 0/256 Tiles, Sample 0/350
# Fra:0 Mem:72.45M (Peak 96.72M) | Time:00:00.51 | Remaining:00:20.24 | Mem:15.89M, Peak:15.96M | Scene, View Layer | Rendered 1/256 Tiles, Sample 350/350
# Fra:0 Mem:72.45M (Peak 96.72M) | Time:00:00.58 | Remaining:00:18.36 | Mem:15.89M, Peak:15.96M | Scene, View Layer | Rendered 2/256 Tiles, Sample 350/350
# Fra:0 Mem:72.45M (Peak 96.72M) | Time:00:00.65 | Remaining:00:17.89 | Mem:15.89M, Peak:15.96M | Scene, View Layer | Rendered 3/256 Tiles, Sample 350/350
# Fra:0 Mem:72.45M (Peak 96.72M) | Time:00:00
| Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 224/256 Tiles, Sample 350/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:23.66 | Remaining:00:19.75 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 225/256 Tiles, Sample 350/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:23.73 | Remaining:00:19.04 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 226/256 Tiles, Sample 350/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:23.81 | Remaining:00:18.33 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 227/256 Tiles, Sample 350/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:23.89 | Remaining:00:17.63 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 228/256 Tiles, Sample 350/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:23.96 | Remaining:00:16.94 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 229/256 Tiles, Sample 350/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:24.04 | Remaining:00:16.25 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 230/256 Tiles, Sample 350/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:24.12 | Remaining:00:15.56 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 231/256 Tiles, Sample 350/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:24.19 | Remaining:00:14.88 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 232/256 Tiles, Sample 350/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:24.27 | Remaining:00:14.21 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 233/256 Tiles, Sample 350/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:24.34 | Remaining:00:13.54 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 234/256 Tiles, Sample 350/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:24.40 | Remaining:00:12.88 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 235/256 Tiles, Sample 350/350
# Fra:3 Mem:72.54M (Peak 108.19M) | Time:02:24.45 | Remaining:00:12.42 | Mem:15.96M, Peak:15.96M | Scene, View Layer | Rendered 235/256 Tiles, Sample 244/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:24.47 | Remaining:00:12.22 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 236/256 Tiles, Sample 350/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:24.54 | Remaining:00:11.56 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 237/256 Tiles, Sample 350/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:24.63 | Remaining:00:10.91 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 238/256 Tiles, Sample 350/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:24.71 | Remaining:00:10.27 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 239/256 Tiles, Sample 350/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:24.79 | Remaining:00:09.63 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 240/256 Tiles, Sample 350/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:24.86 | Remaining:00:09.00 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 241/256 Tiles, Sample 350/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:24.93 | Remaining:00:08.36 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 242/256 Tiles, Sample 350/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:25.01 | Remaining:00:07.74 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 243/256 Tiles, Sample 350/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:25.08 | Remaining:00:07.12 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 244/256 Tiles, Sample 350/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:25.16 | Remaining:00:06.50 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 245/256 Tiles, Sample 350/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:25.24 | Remaining:00:05.89 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 246/256 Tiles, Sample 350/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:25.31 | Remaining:00:05.28 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 247/256 Tiles, Sample 350/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:25.38 | Remaining:00:04.68 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 248/256 Tiles, Sample 350/350
# Fra:3 Mem:72.54M (Peak 108.19M) | Time:02:25.45 | Remaining:00:04.16 | Mem:15.96M, Peak:15.96M | Scene, View Layer | Rendered 248/256 Tiles, Sample 301/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:25.46 | Remaining:00:04.08 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 249/256 Tiles, Sample 350/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:25.53 | Remaining:00:03.48 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 250/256 Tiles, Sample 350/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:25.61 | Remaining:00:02.89 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 251/256 Tiles, Sample 350/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:25.68 | Remaining:00:02.30 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 252/256 Tiles, Sample 350/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:25.76 | Remaining:00:01.72 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 253/256 Tiles, Sample 350/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:25.83 | Remaining:00:01.14 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 254/256 Tiles, Sample 350/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:25.89 | Remaining:00:00.57 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 255/256 Tiles, Sample 350/350
# Fra:3 Mem:72.48M (Peak 108.19M) | Time:02:25.96 | Mem:15.90M, Peak:15.96M | Scene, View Layer | Rendered 256/256 Tiles
# Fra:3 Mem:72.47M (Peak 108.19M) | Time:02:25.96 | Mem:15.89M, Peak:15.96M | Scene, View Layer | Finished
# Fra:3 Mem:72.45M (Peak 108.19M) | Time:02:25.96 | Compositing
# Fra:3 Mem:72.45M (Peak 108.19M) | Time:02:25.96 | Compositing | Determining resolution
# Fra:3 Mem:72.45M (Peak 108.19M) | Time:02:25.96 | Compositing | Initializing execution
# Fra:3 Mem:101.51M (Peak 108.19M) | Time:02:27.41 | Compositing | Tile 1-4
# Fra:3 Mem:101.51M (Peak 108.19M) | Time:02:27.41 | Compositing | Tile 2-4
# Fra:3 Mem:101.51M (Peak 108.19M) | Time:02:27.41 | Compositing | Tile 3-4
# Fra:3 Mem:101.51M (Peak 108.19M) | Time:02:27.41 | Compositing | Tile 4-4
# Fra:3 Mem:101.51M (Peak 108.19M) | Time:02:27.42 | Compositing | Tile 1-4
# Fra:3 Mem:101.51M (Peak 108.19M) | Time:02:27.42 | Compositing | Tile 2-4
# Fra:3 Mem:101.51M (Peak 108.19M) | Time:02:27.42 | Compositing | Tile 3-4
# Fra:3 Mem:101.51M (Peak 108.19M) | Time:02:27.42 | Compositing | Tile 4-4
# Fra:3 Mem:101.51M (Peak 108.19M) | Time:02:27.44 | Compositing | Tile 1-4
# Fra:3 Mem:101.51M (Peak 108.19M) | Time:02:27.47 | Compositing | Tile 2-4
# Fra:3 Mem:101.51M (Peak 108.19M) | Time:02:27.48 | Compositing | Tile 3-4
# Fra:3 Mem:101.51M (Peak 108.19M) | Time:02:27.51 | Compositing | Tile 4-4
# Fra:3 Mem:101.45M (Peak 108.19M) | Time:02:27.51 | Compositing | De-initializing execution
# Saved: /dev/shm/blender_proc_da10daa34abf4235a44766d0dd627bbb/distance_0003.exr
# Saved: /dev/shm/blender_proc_da10daa34abf4235a44766d0dd627bbb/normals_0003.exr
# Fra:3 Mem:77.45M (Peak 108.19M) | Time:02:27.58 | Sce: Scene Ve:0 Fa:0 La:0
# Saved: '/dev/shm/blender_proc_da10daa34abf4235a44766d0dd627bbb/rgb_0003.png'
#  Time: 02:27.68 (Saving: 00:00.10)
#
# #### Finished - Running module RgbRenderer (took 388.072 seconds) ####
# #### Start - Running module Hdf5Writer ####
# Merging data for frame 0 into /home/khaled/nodlabs/BlenderProc/examples/basic/output/0.hdf5
# Key: distance - shape: (512, 512) - dtype: float32 - path: /dev/shm/blender_proc_da10daa34abf4235a44766d0dd627bbb/distance_0000.exr
# Key: normals - shape: (512, 512, 3) - dtype: float32 - path: /dev/shm/blender_proc_da10daa34abf4235a44766d0dd627bbb/normals_0000.exr
# Key: colors - shape: (512, 512, 3) - dtype: uint8 - path: /dev/shm/blender_proc_da10daa34abf4235a44766d0dd627bbb/rgb_0000.png
# Merging data for frame 1 into /home/khaled/nodlabs/BlenderProc/examples/basic/output/1.hdf5
# Key: distance - shape: (512, 512) - dtype: float32 - path: /dev/shm/blender_proc_da10daa34abf4235a44766d0dd627bbb/distance_0001.exr
# Key: normals - shape: (512, 512, 3) - dtype: float32 - path: /dev/shm/blender_proc_da10daa34abf4235a44766d0dd627bbb/normals_0001.exr
# Key: colors - shape: (512, 512, 3) - dtype: uint8 - path: /dev/shm/blender_proc_da10daa34abf4235a44766d0dd627bbb/rgb_0001.png
# Merging data for frame 2 into /home/khaled/nodlabs/BlenderProc/examples/basic/output/2.hdf5
# Key: distance - shape: (512, 512) - dtype: float32 - path: /dev/shm/blender_proc_da10daa34abf4235a44766d0dd627bbb/distance_0002.exr
# Key: normals - shape: (512, 512, 3) - dtype: float32 - path: /dev/shm/blender_proc_da10daa34abf4235a44766d0dd627bbb/normals_0002.exr
# Key: colors - shape: (512, 512, 3) - dtype: uint8 - path: /dev/shm/blender_proc_da10daa34abf4235a44766d0dd627bbb/rgb_0002.png
# Merging data for frame 3 into /home/khaled/nodlabs/BlenderProc/examples/basic/output/3.hdf5
# Key: distance - shape: (512, 512) - dtype: float32 - path: /dev/shm/blender_proc_da10daa34abf4235a44766d0dd627bbb/distance_0003.exr
# Key: normals - shape: (512, 512, 3) - dtype: float32 - path: /dev/shm/blender_proc_da10daa34abf4235a44766d0dd627bbb/normals_0003.exr
# Key: colors - shape: (512, 512, 3) - dtype: uint8 - path: /dev/shm/blender_proc_da10daa34abf4235a44766d0dd627bbb/rgb_0003.png
# #### Finished - Running module Hdf5Writer (took 0.970 seconds) ####
# #### Finished - Running blender pipeline (took 391.483 seconds) ####
#
# Blender quit
# Cleaning temporary directory

# %% [markdown]
# We visualize the first rendered color, depth and normal image which corresponds to the `0.hdf5` file inside the `examples/basic/output` folder

# %%
# visualize the generated data (0.hdf5)

# %run "../../scripts/visHdf5Files.py" "output/0.hdf5"
# Out:
# output/0.hdf5 contains the following keys: <KeysViewHDF5 ['blender_proc_version', 'colors', 'colors_version', 'distance', 'distance_version', 'normals', 'normals_version']>

# %% [markdown]
# We visualize the second rendered color, depth and normal image which corresponds to the `1.hdf5` file inside the `examples/basic/output` folder

# %%
# visualize the generated data (1.hdf5)
# %run "../../scripts/visHdf5Files.py" "output/1.hdf5"
# Out:
# output/1.hdf5 contains the following keys: <KeysViewHDF5 ['blender_proc_version', 'colors', 'colors_version', 'distance', 'distance_version', 'normals', 'normals_version']>

# %%
# visualize the generated data (2.hdf5)
# %run "../../scripts/visHdf5Files.py" "output/2.hdf5"
# Out:
# output/2.hdf5 contains the following keys: <KeysViewHDF5 ['blender_proc_version', 'colors', 'colors_version', 'distance', 'distance_version', 'normals', 'normals_version']>

# %%
# visualize the generated data (3.hdf5)
# %run "../../scripts/visHdf5Files.py" "output/3.hdf5"
# Out:
# output/3.hdf5 contains the following keys: <KeysViewHDF5 ['blender_proc_version', 'colors', 'colors_version', 'distance', 'distance_version', 'normals', 'normals_version']>
